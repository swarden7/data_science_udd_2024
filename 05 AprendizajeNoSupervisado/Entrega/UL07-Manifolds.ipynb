# %% [markdown]
# # **Aprendizaje no supervisado**
# # UL07. Manifolds

# %% [markdown]
# ## <font color='blue'>**Manifolds Learning**</font>
#
# Las distancias euclidianas pueden no funcionar para ciertos problemas debido a la geometría de los datos. Sin embargo, existe una serie de otras métricas que nos permite  superar esto, como por ejemplo  la distancia geodésica. ISOMAP es una de las variedades de aprendizaje más famosas, utiliza la distancia geodésica para comprender los datos.
#
# ## El concepto de manifolds
#
# ![Visualizando](https://drive.google.com/uc?export=view&id=1epAR6zE8u5vX_ETE_rEZphdwQVKbjqGd)
#
# Localmente, la circunferencia parece una línea, que tiene una sola dimensión. En otros términos, una sola coordenada es suficiente para describir un pequeño arco de circunferencia. Consideremos, por ejemplo, la parte superior de la circunferencia, para la que la coordenada y es positiva (la parte amarilla en la figura 1). Cualquier punto de esta parte puede ser descrito por la coordenada x. Existe, por lo tanto, un homeomorfismo entre la parte amarilla de la circunferencia y el intervalo abierto [−1, 1] que representa cada punto de la circunferencia por su primera coordenada.
#
# **Una variedad (Manifolds) n** es un espacio topológico que, en cada punto, tiene una vecindad que es homeomorfa al espacio euclidiano n-dimensional.
#
# En topología, un **homeomorfismo**  es una función de un espacio topológico a otro, que cumple con ser una función biyectiva continua y cuya inversa es continua. En este caso, los dos espacios topológicos se dicen homeomorfos. Las propiedades de estos espacios que se conservan bajo homeomorfismos se denominan propiedades topológicas.

# %% [markdown]
# ### Isomap/Isometric mapping
#
# Es un algoritmo de aprendizaje de variedades que intenta preservar la distancia geodésica entre muestras mientras reduce la dimensión. Miremos un ejemplo concreto.
#
#
# <img src='https://drive.google.com/uc?export=view&id=1hPMnNTJhnzlxLxEkfEhZ6K3PI40qq2Oo' width="300" align="left" style="margin-right: 20px">
#
# <br clear="left">
#
# En la figura anterior, los datos forman una forma de espiral (no lineal). La línea roja determina la distancia geodésica entre x1 y x2, mientras que la línea azul representa la distancia euclidiana.
#
# Como calculamos esta distancia.
#
#
# <img src='https://drive.google.com/uc?export=view&id=1YlmbakUQPzzkvol-qMFpn0gmEKLkmSyE' width="300" align="left" style="margin-right: 20px">
# <br clear="left">

# %% [markdown]
# ### t-SNE (T-distributed Stochastic Neighbor Embedding)
#
# Adaptado de  (https://www.youtube.com/watch?v=NEaUSP4YerM)
#
# ¿Como podemos proyectar para generar una buena separación?
#
# <img src='https://drive.google.com/uc?export=view&id=1PTJq3rG7_pn6jkYoqopeqf2yc270MiNr' width="300" align="left" >
# <br clear="left">
#
# Supongamos que el grupo de puntos los pondemos en forma aleatoria sobre la recta.
#
# <img src='https://drive.google.com/uc?export=view&id=1_5FGWPnrJENgy7LzvmWkNkU3aibquwSx' width="300" align="left" style="margin-right: 20px">
# <br clear="left">
#
# Posteriormente vamos moviendo los puntos en terminos de la similitud entre los datos.
#
#
# <img src='https://drive.google.com/uc?export=view&id=142OstQ7Sixs_guSEHksHAILFBs7-2FrB' width="300" align="left" style="margin-right: 20px">
# <br clear="left">
#
# ¿Como medimos la similitud?, a traves de una matriz de similaridad.
#
# <img src='https://drive.google.com/uc?export=view&id=1niItSDu-U8ztya9VjkQ4Bjg2_W-o16lV' width="300" align="left" style="margin-right: 20px">
# <br clear="left">
#
#
# ¿Como se construye la matriz?
#
# Mida las similitudes entre puntos en el espacio de alta dimensión. Piense en un montón de puntos de datos dispersos en un espacio 2D. Para cada punto de datos ($x_i$), centraremos una distribución gaussiana sobre ese punto. Luego medimos la densidad de todos los puntos ($x_j$) bajo esa distribución gaussiana. Luego renormalice para todos los puntos. Esto nos da un conjunto de probabilidades ($P_{ij}$) para todos los puntos. Esas probabilidades son proporcionales a las similitudes. Todo lo que eso significa es que, si los puntos de datos $x_1$ y $x_2$ tienen valores iguales bajo este círculo gaussiano, entonces sus proporciones y similitudes son iguales y, por lo tanto, tiene similitudes locales en la estructura de este espacio de alta dimensión.
#
# <br clear="left">
# <img src='https://drive.google.com/uc?export=view&id=1L_oOGBDRIUuNIaGFoZwz9Rv1rPrZUQXf' width="300" align="left" style="margin-right: 20px">
#
# <br clear="left">
# <br clear="left">
#
# <img src='https://drive.google.com/uc?export=view&id=16zTYNlFaCc0fcJRdKS2T4gE2Csm690lX' width="300" align="left" style="margin-right: 20px">
# <br clear="left">
#
#
# En lugar de usar una distribución gaussiana, usa una distribución t de Student con un grado de libertad, que también se conoce como distribución de Cauchy . Esto nos da un segundo conjunto de probabilidades ($Q_{ij}$) en el espacio de baja dimensión. Como puede ver, la distribución t de Student tiene colas más pesadas que la distribución normal. Las colas pesadas permiten un mejor modelado de distancias alejadas. Lo cual permite una mejor separación de los puntos.
#
# El último paso es que queremos que este conjunto de probabilidades del espacio de baja dimensión ($Q_{ij}$) refleje las del espacio de alta dimensión ($P_{ij}$) de la mejor manera posible. Queremos que las dos estructuras del mapa sean similares. Medimos la diferencia entre las distribuciones de probabilidad de los espacios utilizando la divergencia de Kullback-Liebler (KL). Finalmente, usamos el descenso de gradiente para minimizar nuestra función de costo KL.
#
# <img src='https://drive.google.com/uc?export=view&id=1NIcKCynfvYBlXriaSvHuvzCHqXIa5Q7Y' width="600" align="Centered" style="margin-right: 20px">
# <br clear="left">

# %% [markdown]
# # <font color='purple' style='bold' size=5>**MATERIAL ADICIONAL** </font>
#
# Profundización de conocimiento especializado en la aplicación de manifold en Python

# %% [markdown]
# - [SCIKIT - MANIFOLD](https://scikit-learn.org/1.5/modules/manifold.html): Documentación oficial de scikit-learn sobre manifold learning, incluyendo implementaciones como Isomap, Locally Linear Embedding (LLE), y t-SNE.
#
#
# - [GITHUB - MANIFOLD LEARNING PYTHON DATA SCIENCE HANDBOOK](https://jakevdp.github.io/PythonDataScienceHandbook/05.10-manifold-learning.html): Una guía detallada sobre manifold learning usando scikit-learn, con ejemplos prácticos como Isomap, t-SNE y MDS.

# %% [markdown]
# ## <font color='purple' style='bold' size=5>**FIN MATERIAL ADICIONAL** </font>

# %% [markdown]
# ## <font color='green'>Actividad 1</font>
#
# Vamos a trabajar con el dataset de digitos.
#
# 1. Carge la libreria de digitos y explorela.
# 2. Aplique los métodos de reducción de dimensionalidad t-SNE, PCA, Kernel-PCA y ISOMAP.
# 3. Visualice las primeras componentes y selecciones el método que genera la mejor separación. Comprenda y utilice la función plot_embedding la cual es proporcionada en el código.
# 4. Construya un modelo que prediga el valor de un digito.

# %%
from time import time
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import offsetbox
from sklearn import (manifold, datasets, decomposition, ensemble,
                     discriminant_analysis, random_projection, neighbors)

# %%
digits = datasets.load_digits(n_class=6)
X = digits.data
y = digits.target
n_samples, n_features = X.shape
n_neighbors = 30

# %%
print(digits.keys())
print("Número de imágenes:", X.shape[0])
print("Número de características:", X.shape[1])
print(digits.feature_names)
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])
# Número de imágenes: 1083
# Número de características: 64
# ['pixel_0_0', 'pixel_0_1', 'pixel_0_2', 'pixel_0_3', 'pixel_0_4', 'pixel_0_5', 'pixel_0_6', 'pixel_0_7', 'pixel_1_0', 'pixel_1_1', 'pixel_1_2', 'pixel_1_3', 'pixel_1_4', 'pixel_1_5', 'pixel_1_6', 'pixel_1_7', 'pixel_2_0', 'pixel_2_1', 'pixel_2_2', 'pixel_2_3', 'pixel_2_4', 'pixel_2_5', 'pixel_2_6', 'pixel_2_7', 'pixel_3_0', 'pixel_3_1', 'pixel_3_2', 'pixel_3_3', 'pixel_3_4', 'pixel_3_5', 'pixel_3_6', 'pixel_3_7', 'pixel_4_0', 'pixel_4_1', 'pixel_4_2', 'pixel_4_3', 'pixel_4_4', 'pixel_4_5', 'pixel_4_6', 'pixel_4_7', 'pixel_5_0', 'pixel_5_1', 'pixel_5_2', 'pixel_5_3', 'pixel_5_4', 'pixel_5_5', 'pixel_5_6', 'pixel_5_7', 'pixel_6_0', 'pixel_6_1', 'pixel_6_2', 'pixel_6_3', 'pixel_6_4', 'pixel_6_5', 'pixel_6_6', 'pixel_6_7', 'pixel_7_0', 'pixel_7_1', 'pixel_7_2', 'pixel_7_3', 'pixel_7_4', 'pixel_7_5', 'pixel_7_6', 'pixel_7_7']

# %%
# Escalar y visualizar los vectores de embeddings
def plot_embedding(X, title=None):
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    # Estamos normalizando los datos.
    X = (X - x_min) / (x_max - x_min)
    plt.figure()
    ax = plt.subplot(111)
    for i in range(X.shape[0]):
      # Posición y valor del texto.
        plt.text(X[i, 0], X[i, 1], str(y[i]),
                 color=plt.cm.Set1(y[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})

    if hasattr(offsetbox, 'AnnotationBbox'):

        shown_images = np.array([[1., 1.]])
        for i in range(X.shape[0]):
            dist = np.sum((X[i] - shown_images) ** 2, 1)
            if np.min(dist) < 4e-3:
                # No mostrar valores muy cercanos
                continue
            shown_images = np.r_[shown_images, [X[i]]]
            imagebox = offsetbox.AnnotationBbox(
                offsetbox.OffsetImage(digits.images[i], cmap=plt.cm.gray_r),
                X[i])
            ax.add_artist(imagebox)
    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)

# %%
n_img_per_row = 20
img = np.zeros((10 * n_img_per_row, 10 * n_img_per_row))
for i in range(n_img_per_row):
    ix = 10 * i + 1
    for j in range(n_img_per_row):
        iy = 10 * j + 1
        img[ix:ix + 8, iy:iy + 8] = X[i * n_img_per_row + j].reshape((8, 8))

plt.imshow(img, cmap=plt.cm.binary)
plt.xticks([])
plt.yticks([])
plt.title('Una seleccion del dataset de digitos con 64 dimensiones (cada digito)')
# Out:
# Text(0.5, 1.0, 'Una seleccion del dataset de digitos con 64 dimensiones (cada digito)')

# %%
# Tu código aquí ...
from sklearn.manifold import TSNE


#t-SNE
X_tsne = TSNE(n_components=2, random_state=0).fit_transform(X)

#viz
plot_embedding(X_tsne, 't-SNE de Digits Dataset')

# %%
# PCA
pca = decomposition.PCA(n_components=2)
X_pca = pca.fit_transform(X)

#viz
plot_embedding(X_pca, 'PCA de Digits Dataset')

# %%
# kernelPCA
kernel_pca = decomposition.KernelPCA(n_components=2, kernel='rbf', gamma=15)
X_kernel_pca = kernel_pca.fit_transform(X)

# viz
plot_embedding(X_kernel_pca, 'Kernel PCA de Digits Dataset')

# %%
# ISOMAP
from sklearn.manifold import Isomap
X_isomap = Isomap(n_components=2, n_neighbors=n_neighbors).fit_transform(X)

# Visualizar
plot_embedding(X_isomap, 'ISOMAP de Digits Dataset')
plt.show()

# %% [markdown]
# <font color='green'>Fin Actividad 1</font>

# %% [markdown]
# ## <font color='green'>Actividad 2</font>
# Una aplicación de las diferentes técnicas de aprendizaje en variedades a un conjunto de datos esféricos. Aquí se puede ver el uso de la reducción de dimensionalidad para ganar algo de intuición sobre los algunos métodos de aprendizaje en variedades.

# %%
from time import time

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import NullFormatter
from sklearn import manifold
from sklearn.utils import check_random_state

# %%
# Crear la esfera
Axes3D

# Variables for manifold learning.
n_neighbors = 10
n_samples = 1000
random_state = check_random_state(0)
p = random_state.rand(n_samples) * (2 * np.pi - 0.55)
t = random_state.rand(n_samples) * np.pi

# Sever the poles from the sphere.
indices = ((t < (np.pi - (np.pi / 8))) & (t > ((np.pi / 8))))
colors = p[indices]
x, y, z = np.sin(t[indices]) * np.cos(p[indices]), \
    np.sin(t[indices]) * np.sin(p[indices]), \
    np.cos(t[indices])

# Plot our dataset.
fig = plt.figure(figsize=(15, 8))
plt.suptitle("Manifold Learning with %i points, %i neighbors"
             % (1000, n_neighbors), fontsize=14)

ax = fig.add_subplot(251, projection='3d')
ax.scatter(x, y, z, c=p[indices], cmap=plt.cm.rainbow)
ax.view_init(40, -10)

sphere_data = np.array([x, y, z]).T

# %% [markdown]
# ### Aplique los metodos t-SNE, ISOMAP y PCA a un dataset esférico
#
# 1. Transforme el dataset
# 2. Visualice las primeras dos componentes en un grafico tipo scatter.
# 3. Discuta los resultados. Evalue visualmente el resultado y comente los tiempos de ejecución de cada tecnica.

# %%
# Tu código aquí ...
# PCA
start_time = time()
pca = decomposition.PCA(n_components=2)
X_pca = pca.fit_transform(sphere_data)
pca_time = time() - start_time
print(f"Tiempo de ejecución: {pca_time}")
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=p[indices])
plt.title("PCA")
plt.show()
# Out:
# Tiempo de ejecución: 0.002549886703491211

# %%
# ISOMAP
start_time = time()
isomap = manifold.Isomap(n_neighbors=n_neighbors, n_components=2)
X_isomap = isomap.fit_transform(sphere_data)
isomap_time = time() - start_time
print(f"Tiempo de ejecución: {isomap_time}")
plt.scatter(X_isomap[:, 0], X_isomap[:, 1], c=p[indices])
plt.title("ISOMAP")
plt.show()
# Out:
# Tiempo de ejecución: 0.4409341812133789

# %%
# t-SNE
start_time = time()
tsne = TSNE(n_components=2, random_state=0)
X_tsne = tsne.fit_transform(sphere_data)
tsne_time = time() - start_time
print(f"Tiempo de ejecución: {tsne_time}")
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=p[indices])
plt.title("t-SNE")
plt.show()
# Out:
# Tiempo de ejecución: 6.391503095626831

# %%
# Configuración de la figura para gráficos
fig, axs = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle('Reducción de Dimensionalidad en el Dataset Esférico', fontsize=16)

# Gráfico PCA
axs[0].scatter(X_pca[:, 0], X_pca[:, 1], c=p[indices], cmap=plt.cm.rainbow)
axs[0].set_title('PCA')
axs[0].set_xlabel('Componente 1')
axs[0].set_ylabel('Componente 2')

# Gráfico ISOMAP
axs[1].scatter(X_isomap[:, 0], X_isomap[:, 1], c=p[indices], cmap=plt.cm.rainbow)
axs[1].set_title('ISOMAP')
axs[1].set_xlabel('Componente 1')
axs[1].set_ylabel('Componente 2')

# Gráfico t-SNE
axs[2].scatter(X_tsne[:, 0], X_tsne[:, 1], c=p[indices], cmap=plt.cm.rainbow)
axs[2].set_title('t-SNE')
axs[2].set_xlabel('Componente 1')
axs[2].set_ylabel('Componente 2')

plt.show()

# Imprimir tiempos de ejecución
print(f"Tiempo PCA: {pca_time:.4f} segundos")
print(f"Tiempo ISOMAP: {isomap_time:.4f} segundos")
print(f"Tiempo t-SNE: {tsne_time:.4f} segundos")
# Out:
# Tiempo PCA: 0.0025 segundos
# Tiempo ISOMAP: 0.4409 segundos
# Tiempo t-SNE: 6.3915 segundos

# %% [markdown]
# De los 3 métodos el primero (PCA) fue el que tomó el menor tiempo de ejecución y el que representó la esfera lo más cercano a su figura de 2 dimensiones.

# %% [markdown]
# <font color='green'>Fin Actividad 2</font>

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1UT8QmOplTfNn0iH3FTtAQhXCHzS0M6si" width="100" align="left" title="Runa-perth">
# <br clear="left">
#
# ## <font color='black'>**Contenido opcional**</font>
#
# ## <font color='blue'>**ICA**</font>
#
# <img src='https://drive.google.com/uc?export=view&id=1X81nmlZUhroOJfgU8vbVLGzkEy2ukcDr' width="500" align="centered" >
# <br/>
#
# Análisis de Componentes Independientes, o ICA para abreviar. ICA es un método computacional para separar una señal multivariante en sus componentes subyacentes. Con ICA, podemos extraer el componente deseado de la fusión de múltiples señales.
#
#
# ## Precondiciones
#
# La primera condición previa para que funcione el algoritmo es que las señales mixtas sean una combinación lineal de cualquier número de señales fuente.
#
# La segunda condición previa es que las señales fuente sean independientes. Entonces, ¿qué significa independencia? Dos señales son independientes si la información de la señal $s1$ no proporciona ninguna información sobre la señal $s2$. Esto implica que no están correlacionados, lo que significa que su covarianza es 0. Sin embargo, hay que tener cuidado aquí, ya que la falta de correlación no significa automáticamente independencia.
#
# La tercera condición previa es que los componentes independientes no sean gaussianos. ¿Porqué es eso? La distribución de densidad conjunta de dos señales independientes no gaussianas será uniforme en un cuadrado;
#
#
# En un nivel general, ICA se puede dividir en los siguientes pasos.
# 1. Centro $x$ restando la media
# 2. *Whitening* $x$
# 3. Elija un valor inicial aleatorio para la matriz de desmezcla $w$
# 4. Calcule el nuevo valor de $w$
# 5. Normalizar $w$
# 6. Compruebe si el algoritmo ha convergido y, si no, vuelva al paso 4
# 7. Tome el producto escalar de $w$ y $x$ para obtener las señales de fuente independientes
#
# __Que significa *Whitening*__
#
# *Whitening* una señal dada significa que la transformamos de tal manera que se eliminan las correlaciones potenciales entre sus componentes (covarianza igual a 0) y la varianza de cada componente es igual a 1. Otra forma de verlo es que la matriz de covarianza de la señal *Whitening* será igual a la matriz de identidad.
#
#
#
# ```python
# def whitening(X):
#     cov = np.cov(X) # Matria de covarianza
#     d, E = np.linalg.eigh(cov) # Autovalores y Autovectores
#     D = np.diag(d) # Matriz de 3x3 con los valores de los autovalores
#     D_inv = np.sqrt(np.linalg.inv(D)) # Invertimos para que valgan 1.
#     X_whiten = np.dot(E, np.dot(D_inv, np.dot(E.T, X)))
#     return X_whiten
# ```

# %% [markdown]
# ¿Cómo funciona? Como se discutió anteriormente, una condición previa para que ICA funcione es que nuestras señales de origen no sean gaussianas. Una cosa interesante acerca de dos señales independientes no gaussianas es que su suma es más gaussiana que cualquiera de las señales fuente. Por lo tanto, necesitamos optimizar $W$ de manera que las señales resultantes de $W_x$ sean lo más no gaussianas posible. Para hacerlo, necesitamos una medida de gaussianidad. La medida más simple sería la curtosis, que es el cuarto momento de los datos y mide la "cola" de una distribución. Sin embargo para una mejor convergencia se utiliza
#
#
# $$g(\mu) = \tanh(\mu)$$
#
# junto con su derivada
#
# $$g'(\mu) = 1 - \tanh^2(\mu)$$
#
# Fuente: *Tichavský, P., Koldovský, Z., & Oja, E. (2007, September). Speed and accuracy enhancement of linear ICA techniques using rational nonlinear functions. In International Conference on Independent Component Analysis and Signal Separation (pp. 285-292). Springer, Berlin, Heidelberg.*

# %% [markdown]
# ## <font color='green'>Actividad 3</font>
#
# Considere las siguientes señales:
#
#
#
# ```python
# n_samples = 2000
# time = np.linspace(0, 8, n_samples)
# s1 = np.sin(2 * time)
# s2 = np.sign(np.sin(3 * time)) # square signal
# s3 = signal.sawtooth(2 * np.pi * time)
# ```
#
# 1. Grafique las señales originales
#
# 2. Combine las señales como por ejemplo :
#
#
# ```python
# X = np.c_[s1, s2, s3]
# A = np.array(([[1, 1, 1], [0.5, 2, 1.0], [1.5, 1.0, 2.0]]))
# X = np.dot(X, A.T)
# ```
# 4. Grafique las señales mezcladas
# 5. Aplique FastICA y vuelva a graficar.
# 6. Compare con PCA.

# %%
import numpy as np
np.random.seed(0)
from scipy import signal
from scipy.io import wavfile
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.decomposition import FastICA, PCA

# %%
def plot_mixture_sources_predictions(X, original_sources, S):
    fig = plt.figure()
    plt.subplot(3, 1, 1)
    for x in X:
        plt.plot(x)
    plt.title("mixtures")
    plt.subplot(3, 1, 2)
    for s in original_sources:
        plt.plot(s)
    plt.title("real sources")
    plt.subplot(3,1,3)
    for s in S:
        plt.plot(s)
    plt.title("predicted sources")

    fig.tight_layout()
    plt.show()

# %%
n_samples = 2000
time = np.linspace(0, 8, n_samples)
s1 = np.sin(2 * time)
s2 = np.sign(np.sin(3 * time)) # square signal
s3 = signal.sawtooth(2 * np.pi * time)

# %%
# Graficar las señales
plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.plot(time, s1)
plt.title('Señal senoidal')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid(True)

plt.subplot(3, 1, 2)
plt.plot(time, s2)
plt.title('Señal cuadrada')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid(True)

plt.subplot(3, 1, 3)
plt.plot(time, s3)
plt.title('Señal diente de sierra')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Combinar las señales
X = np.c_[s1, s2, s3]

# Matriz de transformación
A = np.array([[1, 0.5, 1.5], [1, 2, 1.0], [1, 1.0, 2.0]])

# Señales combinadas
X_combined = np.dot(X, A.T)

# Graficar las señales combinadas
plt.figure(figsize=(10, 6))

for i in range(X_combined.shape[1]):
    plt.subplot(X_combined.shape[1], 1, i + 1)
    plt.plot(time, X_combined[:, i])
    plt.title(f'Señal combinada {i+1}')
    plt.xlabel('Tiempo')
    plt.ylabel('Amplitud')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Aplicar FastICA
ica = FastICA(n_components=3)
S_ica = ica.fit_transform(X_combined)

# Graficar las señales combinadas y las señales recuperadas por FastICA
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
plt.title('Señales combinadas')
for sig in X_combined.T:
    plt.plot(time, sig)
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid(True)

plt.subplot(2, 1, 2)
plt.title('Señales recuperadas por FastICA')
for sig in S_ica.T:
    plt.plot(time, sig)
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Aplicar PCA
pca = PCA(n_components=3)
S_pca = pca.fit_transform(X_combined)

# Graficar las señales originales, combinadas y recuperadas por PCA y FastICA
plt.figure(figsize=(12, 10))

# Señales originales
plt.subplot(4, 1, 1)
plt.title('Señales originales')
for sig in X.T:
    plt.plot(time, sig)
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid(True)

# Señales combinadas
plt.subplot(4, 1, 2)
plt.title('Señales combinadas')
for sig in X_combined.T:
    plt.plot(time, sig)
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid(True)

# Señales recuperadas por PCA
plt.subplot(4, 1, 3)
plt.title('Señales recuperadas por PCA')
for sig in S_pca.T:
    plt.plot(time, sig)
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid(True)

# Señales recuperadas por FastICA
plt.subplot(4, 1, 4)
plt.title('Señales recuperadas por FastICA')
for sig in S_ica.T:
    plt.plot(time, sig)
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# <font color='green'>Fin Actividad 3</font>
#
# <img src="https://drive.google.com/uc?export=view&
# id=1UT8QmOplTfNn0iH3FTtAQhXCHzS0M6si" width="50" align="left" title="Runa-perth">

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1bqkJJ7QiIOTsp-7jm5eUtK-XYWMEq2_K" width="100" align="left" />
# <br clear="left">
#
# ## <font color='blue'>**Resumen**</font>
#
# Resumen de t-SNE (t-distributed Stochastic Neighbor Embedding):
#
# t-SNE es una técnica de reducción de dimensionalidad no lineal utilizada principalmente para visualizar datos de alta dimensionalidad en un espacio bidimensional o tridimensional. Su objetivo es preservar la estructura local de los datos, manteniendo las distancias entre puntos similares y disminuyendo las distancias entre puntos no similares.
#
# Funcionamiento:
#
# 1. Medición de similitudes: t-SNE calcula las similitudes entre pares de puntos en el espacio de alta dimensión utilizando una distribución de probabilidad basada en la distancia euclidiana.
#
# 2. Reducción de dimensionalidad: Luego, t-SNE mapea los datos a un espacio de baja dimensión, como 2D o 3D, de manera que la similitud de los puntos se conserve en la medida de lo posible.
#
# Ventajas de t-SNE:
#
# 1. Preservación de estructura local: t-SNE es efectivo para preservar la estructura local y agrupaciones de datos en un espacio de baja dimensión.
#
# 2. Visualización de datos complejos: Es útil para visualizar datos complejos en 2D o 3D para la identificación de patrones y relaciones.
#
# Desventajas de t-SNE:
#
# 1. Costo computacional: t-SNE puede ser computacionalmente costoso para grandes conjuntos de datos debido a la alta dimensionalidad y la necesidad de calcular las similitudes de cada par de puntos.
#
# 2. No siempre preserva la estructura global: t-SNE puede tener dificultades para preservar la estructura global de los datos y puede comprimir regiones densas de puntos.
#
# Ejemplos de aplicaciones de t-SNE:
#
# 1. Visualización de datos en aprendizaje automático: t-SNE es ampliamente utilizado para visualizar características y embeddings en tareas de clasificación y agrupamiento.
#
# 2. Visualización de datos biológicos: En bioinformática, t-SNE se aplica para visualizar datos de expresión genética y agrupar células en estudios de células individuales.
#
# 3. Procesamiento de lenguaje natural: En el análisis de texto, t-SNE puede visualizar embeddings de palabras o documentos para entender relaciones semánticas.
#
# Resumen de Isomap:
#
# Isomap es una técnica de reducción de dimensionalidad no lineal que se basa en la estructura geométrica de los datos. Su objetivo es preservar las distancias geodésicas (distancias a lo largo de las curvas más cortas en una variedad) entre puntos en un espacio de baja dimensión.
#
# Funcionamiento:
#
# 1. Cálculo de vecindades: Isomap encuentra los k vecinos más cercanos de cada punto en el espacio de alta dimensión.
#
# 2. Construcción del grafo: Luego, construye un grafo de vecinos conectando puntos con aristas ponderadas según las distancias euclidianas entre ellos.
#
# 3. Cálculo de distancias geodésicas: Isomap estima las distancias geodésicas entre todos los pares de puntos utilizando el algoritmo de Dijkstra.
#
# 4. Reducción de dimensionalidad: Finalmente, mapea los datos a un espacio de baja dimensión utilizando técnicas de análisis de componentes principales.
#
# Ventajas de Isomap:
#
# 1. Preservación de estructura global: Isomap es efectivo para preservar la estructura global y la conectividad de los datos en un espacio de baja dimensión.
#
# 2. Robustez frente a datos ruidosos: Es menos sensible al ruido y a valores atípicos en comparación con otras técnicas de reducción de dimensionalidad.
#
# Desventajas de Isomap:
#
# 1. Costo computacional: Al igual que t-SNE, Isomap puede ser computacionalmente costoso para grandes conjuntos de datos debido al cálculo de las distancias geodésicas.
#
# Ejemplos de aplicaciones de Isomap:
#
# 1. Visualización y análisis de datos de sensores: Isomap es útil para visualizar y entender datos de sensores multidimensionales en entornos IoT y sistemas embebidos.
#
# 2. Procesamiento de imágenes: En visión por computadora, Isomap puede ser utilizado para reducir la dimensionalidad de características de imágenes para tareas de reconocimiento y clasificación.
#
# 3. Análisis de datos geoespaciales: En geoinformática, Isomap se aplica para visualizar y analizar datos de ubicaciones geográficas en espacios de baja dimensión.
#
# En resumen, t-SNE y Isomap son técnicas de reducción de dimensionalidad no lineales con el objetivo de preservar la estructura y la conectividad de los datos en un espacio de baja dimensión. Ambos son útiles para visualizar datos complejos y entender las relaciones entre puntos en conjuntos de datos de alta dimensionalidad. Sin embargo, es importante seleccionar la técnica adecuada según los requisitos específicos de la aplicación y considerar el costo computacional para conjuntos de datos grandes.

# %% [markdown]
# # <font color='purple' style='bold' size=5>**REFLEXION GRUPAL** </font>

# %% [markdown]
# Durante este módulo, hemos explorado técnicas fundamentales del aprendizaje no supervisado, que son esenciales para cualquier profesional en ciencia de datos. Estas técnicas nos permiten descubrir patrones ocultos en los datos, reducir la dimensionalidad y mejorar la comprensión de las estructuras subyacentes en los conjuntos de datos.
# Aprendimos que la selección de características es crucial para eliminar variables irrelevantes o redundantes, lo que mejora la eficiencia computacional y reduce el riesgo de sobreajuste. Al reducir la dimensionalidad y seleccionar características relevantes, podemos mejorar la precisión y eficiencia de nuestros modelos predictivos.
#
# Al finalizar este módulo, hemos logrado consolidar nuestra comprensión sobre el aprendizaje no supervisado, una rama fundamental del aprendizaje automático que nos permite identificar patrones ocultos en los datos sin necesidad de etiquetas predefinidas. A través de los ejercicios y clases, hemos explorado diversas técnicas de clustering, reducción de dimensionalidad y selección de características, fortaleciendo nuestra capacidad para analizar conjuntos de datos complejos y extraer información valiosa.
#
# El clustering ha sido una de las áreas clave en nuestro aprendizaje. Comenzamos con el algoritmo K-Means, que nos permitió agrupar datos en clústeres bien definidos en función de sus similitudes. Aprendimos a ajustar el número de clústeres óptimo utilizando el método del codo y la silueta, comprendiendo la importancia de elegir la mejor configuración para lograr segmentaciones precisas.
#
# Posteriormente, exploramos DBSCAN, un método basado en densidad que nos permitió identificar agrupaciones de datos con formas más complejas y manejar valores atípicos de manera efectiva. A diferencia de K-Means, DBSCAN no requiere especificar el número de clústeres de antemano, lo que lo hace una herramienta flexible para conjuntos de datos con estructuras menos definidas.
#
# También profundizamos en el clustering jerárquico, una técnica que nos permitió visualizar las relaciones entre los datos en forma de dendrogramas. Esta metodología es útil para obtener una visión global de las similitudes entre los elementos y establecer jerarquías dentro de los conjuntos de datos.
#
# En cuanto a la reducción de dimensionalidad, trabajamos con Análisis de Componentes Principales (PCA), lo que nos permitió representar los datos en espacios de menor dimensión sin perder información significativa. Esta técnica es clave para mejorar el rendimiento de los modelos y facilitar la visualización de datos en problemas de alta dimensionalidad. Complementamos este aprendizaje con el estudio de Manifolds, que nos permitió comprender cómo las estructuras no lineales en los datos pueden ser representadas en espacios de menor dimensión preservando su estructura inherente.
#
# Además, exploramos la selección de características, un proceso fundamental para mejorar la eficiencia de los modelos eliminando variables redundantes o irrelevantes. Esto nos permitió reducir la complejidad computacional y mejorar la interpretabilidad de los resultados obtenidos.
#
# El proyecto final del módulo nos permitió aplicar estos conocimientos en un caso práctico, en el que implementamos diversas técnicas de aprendizaje no supervisado para extraer información útil de grandes volúmenes de datos. Esta experiencia nos permitió integrar todos los conceptos aprendidos y reflexionar sobre su aplicabilidad en distintos contextos profesionales.
#
# **Alejandro**
#
# De lo visto en este módulo, me interesó mucho la importancia de la selección de características. Pensando en la realidad de mi trabajo, al seleccionar las características más relevantes de nuestros datos de rendimiento de cultivos, podemos identificar qué factores ambientales y genéticos influyen más en la productividad. Esto nos permite optimizar nuestros programas de mejoramiento genético y desarrollar variedades más resilientes.
#
# También en mi trabajo como analista en una empresa semillera, el aprendizaje no supervisado ha demostrado ser una herramienta invaluable para segmentar cultivos y analizar patrones en la producción agrícola. DBSCAN me ha permitido identificar zonas con características similares sin necesidad de una clasificación previa, lo que facilita la toma de decisiones en la optimización del uso de fertilizantes y agua. Además, el clustering jerárquico ha sido útil para entender la relación entre diferentes variedades de semillas y su rendimiento en distintas condiciones ambientales, ayudando a mejorar las estrategias de producción y comercialización.
#
# **Fernanda**
#
# Durante el módulo de Aprendizaje No Supervisado en mi diplomado de Ciencia de Datos, adquirí herramientas fundamentales para el desarrollo de modelos de optimización en plantas de tratamiento de agua, que es el enfoque principal de nuestro trabajo en Ainwater. En nuestro día a día, trabajamos con bases de datos extensas, llenas de variables operacionales y de calidad del agua. Sin embargo, no todas las variables aportan el mismo valor para la toma de decisiones.
#
# En este contexto, técnicas como el Análisis de Componentes Principales (PCA) son clave para reducir la dimensionalidad de los datos sin perder información esencial. Esto nos permite enfocarnos en las variables más relevantes y disminuir la complejidad de los modelos, mejorando su eficiencia y capacidad de interpretación.
#
# Por otro lado, la agrupación de datos mediante clustering nos permite identificar patrones de comportamiento en las plantas, los cuales muchas veces están influenciados por factores como la estacionalidad o ciertos modos de operación. Detectar estos grupos nos ayuda a desarrollar modelos más precisos para sugerir acciones operacionales adaptadas a cada escenario, optimizando así el rendimiento de las plantas.
#
# En definitiva, el Aprendizaje No Supervisado nos proporciona herramientas para hacer que los modelos de IA sean más robustos y eficientes, alineando los datos con el propósito final de mejorar la toma de decisiones en el tratamiento de agua.
#
# **Gonzalo**
#
# Como ingeniero de estudios en AIEP, una de las instituciones de educación superior técnico-profesional más grandes e importantes de Chile, mi rol implica analizar grandes volúmenes de datos para generar reportes y estudios que apoyen la toma de decisiones. El aprendizaje no supervisado ha sido clave para mejorar la segmentación de estudiantes según sus características académicas y comportamientos, permitiéndonos diseñar estrategias de retención más efectivas y optimizar la asignación de recursos. Herramientas como K-Means y PCA han sido particularmente útiles para descubrir patrones en los datos y reducir la dimensionalidad de los análisis, facilitando la generación de informes más comprensibles y accionables.
#
# **Rodrigo:**
#
# En mi experiencia, el aprendizaje no supervisado ha sido una herramienta clave para mejorar la exploración y el análisis de datos en proyectos de analítica avanzada. La combinación de técnicas de clustering y reducción de dimensionalidad nos ha permitido descubrir estructuras en los datos que de otro modo serían difíciles de identificar. Este módulo no solo ha fortalecido nuestra competencia técnica, sino que también nos ha preparado para aplicar estos conocimientos en proyectos futuros, impulsando la toma de decisiones basada en datos dentro de nuestras respectivas áreas profesionales.
#
# **Conclusión**
#
# El aprendizaje no supervisado nos ha permitido comprender mejor la estructura de los datos sin la necesidad de etiquetas previas, ampliando nuestras capacidades analíticas y de exploración. A través de los distintos algoritmos de clustering, reducción de dimensionalidad y selección de características, hemos adquirido herramientas valiosas para enfrentar desafíos en múltiples ámbitos profesionales. Este módulo no solo nos ha brindado conocimientos técnicos esenciales, sino que también ha fortalecido nuestra capacidad para aplicar estos enfoques en situaciones reales, facilitando el descubrimiento de patrones ocultos y la toma de decisiones informadas en distintos sectores.
