# %% [markdown]
# # **Introducción a Python**
# ## FP09. Booleans

# %% [markdown]
# Los booleanos son tipos de datos que indican un estado lógico de **Verdadero** o **Falso**.
#
# Python también tiene un objeto llamado __None__, el cual es un valor especial que se utiliza para indicar la ausencia de un valor o la falta de asignación. Se utiliza para representar la falta de un objeto o la ausencia de información.
#
# Exploremos cómo se ven estos tipos. Trabajaremos con ellos mucho más una vez que comencemos a aprender sobre el flujo de control con Python, pero hasta entonces, vamos a entender cómo se ven.
#
# TIP: `True`, `False` y `None` son palabras reservadas de Python.

# %%
# Booleanos

a = True

# %%
a
# Out:
# True

# %%
type(a)
# Out:
# bool

# %%
b = False

# %%
type(b)
# Out:
# bool

# %%
False
# Out:
# False

# %%
0 == False
# Out:
# True

# %%
True
# Out:
# True

# %%
1 == True
# Out:
# True

# %%
0 == True
# Out:
# False

# %%
None == False
# Out:
# False

# %%
[] == False
# Out:
# False

# %%
{} == None
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
True and False
# Out:
# False

# %%
(True or False) and False or True
# Out:
# True

# %% [markdown]
# ## <font color='blue'>**Operadores de comparación**</font>
# Hemos visto operadores de comparación anteriormente, pero repasemos rápidamente todos ellos:

# %%
# Less Than (menor que)
1 < 2
# Out:
# True

# %%
# Great Than (mayor que)
1 > 2
# Out:
# False

# %%
# Check for equality (igualdad)
1 == 1
# Out:
# True

# %%
# Check for inequality (desigualdad)
1 != 1
# Out:
# False

# %%
# Less than or equal to (menor o igua que)
1 <= 3
# Out:
# True

# %%
# Greater than of equal to (mayor o igual que)
1 >= 1
# Out:
# True

# %%
1 > 2
# Out:
# False

# %%
2 == 2
# Out:
# True

# %% [markdown]
# ## <font color='blue'>**Operadores lógicos (_Logical Operators_)**</font>
#
# Ahora que conocemos los operadores de comparación, podemos usar operadores lógicos para combinar múltiples comparaciones (en general, múltiples declaraciones booleanas)

# %% [markdown]
# ### __El operador `and`__
# Úsalo cuando quieras comprobar que ambas declaraciones son verdaderas (`True`)

# %%
# Verdadero y Verdadero es Verdadero

1 == 1 and 2 == 2
# Out:
# True

# %%
# Verdadero y Falso es Falso
1 == 1 and 2 == 1
# Out:
# False

# %%
# Falso y Falso es Falso
1 == 2 and 2 == 1
# Out:
# False

# %%
#inicio de experimiento
1 + True == True + True
#fin de experimento
# Out:
# True

# %% [markdown]
# ### __El operador `or`__
# Úsalo cuando solo una declaración debe ser verdadera (`True`)

# %%
# Verdadero o Verdadero es Verdadero

1 == 1 or 2 == 2
# Out:
# True

# %%
# Verdadero o Falso es Verdadero

1 == 1 or 2 == 10
# Out:
# True

# %%
# Falso o Falso es Falso

1 == 2 or 2 == 10
# Out:
# False

# %% [markdown]
# ### __El operador `not`__
# El operador `not`  invierte el valor booleano

# %%
not 1 == 1
# Out:
# False

# %%
# No es muy común ver algo como esto, pero funciona

1 == 1 and not 2 == 3
# Out:
# True

# %%
# Un ejemplo más realista

respuesta = 'no'
if 1 == 1 and not respuesta == 'yes':
    print("Exito!")
# Out:
# Exito!

# %%
# Lo mismo

respuesta = 'no'
if 1 ==1 and respuesta != 'yes':
    print("Exito!")
# Out:
# Exito!

# %% [markdown]
# Podemos usar `None` como marcador de posición para un objeto que no queremos reasignar todavía:

# %%
c = None

# %%
type(c)
# Out:
# NoneType

# %% [markdown]
# Es muy sencillo !!

# %% [markdown]
# ## <font color='blue'>__Ejercicios__</font>

# %% [markdown]
# ### <font color='green'>Actividad 1: </font>
# ### Trabajando con Operadores Lógicos
# ¿Cuál es el resultado (`True` o `False`) de una expresión como esta?
# ```Python
#     True and False or True and False
# ```

# %%
# Tu código aquí ...
True and False or True and False

# El operador and tiene mayor precedencia que el operador or, por lo que se evaluarán primero los operadores and y luego el or.
# True and False es False, True and False es False. Luego, se evalúa el operador or:
# False or False es False. El resultado final es False.
# Out:
# False

# %% [markdown]
# <font color='green'>Fin actividad 1</font>

# %% [markdown]
# ### <font color='green'>Actividad 2: </font>
# ### Trabajando con Operadores Lógicos
#
# ¿Cuál es el resultado (`True` o `False`) de una expresión como esta?
# ```Python
#     True or False and True or False
# ```

# %%
# Tu código aquí ...
True or False and True or False
# El operador and tiene mayor precedencia que el operador or, por lo que se evaluarán primero los operadores and y luego el or.
# False and True es False. Luego, se evalúa el operador or:
# True or False es True, True or False es True. El resultado final es True.
# Out:
# True

# %% [markdown]
# <font color='green'>Fin actividad 2</font>

# %% [markdown]
# ### <font color='green'>Actividad 3: </font>
# ### Trabajando con Operadores Lógicos
# Escribe una expresión como la siguiente, pero usando números
# ```Python
#     True or False and True or False
# ```
# Tip:
# ```Python
#     1 == 1
#     True
# ```

# %%
# Tu código aquí ...
1 == 1 or 1 == 2 and 2 > 1 or 2 == 3
# Out:
# True

# %% [markdown]
# <font color='green'>Fin actividad 3</font>
